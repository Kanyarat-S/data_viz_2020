# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanyarat-S/data_viz_2022/blob/main/Final_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive #เชื่อมเข้ากับ Drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os #os เอาไว้จัดการไฟล์และ path

# %%
path = '/content/drive/My Drive/DataViz22_data'

# %%
alldb = pd.read_csv(os.path.join(path, 'alldb.csv'))

# %%
hospital = os.path.join(path,'hospital_list.xlsx')
hospital = pd.read_excel(hospital)

# %% [markdown]
# ###ข้อมูล alldb

# %%
alldb
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# 0      NaN         NaN  NaN               NaN    NaN       NaN
# 1      NaN  2022-02-24  NaN        iPhone10,4  05310  10:50:32
# 2      NaN         NaN  NaN               NaN    NaN       NaN
# 3      NaN  2022-02-23    0        iPhone13,4  05087  09:59:47
# 4      NaN  2022-02-23  NaN        iPhone13,4  05087  09:44:06
# ...    ...         ...  ...               ...    ...       ...
# 40030  NaN         NaN  NaN        iPhone13,4  01234       NaN
# 40031  NaN         NaN    2        iPhone10,5  01234       NaN
# 40032  NaN         NaN    1        iPhone13,4  01234       NaN
# 40033  NaN         NaN  NaN  Samsung SM-A115F  01234       NaN
# 40034  NaN         NaN    1  Samsung SM-A115F  01234       NaN
#
#                  urine  pid            PartitionKey                  title  \
# 0                  NaN  NaN                     NaN  data is not completed
# 1                  NaN  NaN                     NaN  data is not completed
# 2                  NaN  NaN                     NaN  data is not completed
# 3      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# 4      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# ...                ...  ...                     ...                    ...
# 40030              NaN    5     เกษศิรินทร์  ไชยลาภ  data is not completed
# 40031  ปกติ (เหลืองใส)    5  เถลิงเกียรติ เสริฐเลิศ  data is not completed
# 40032  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
# 40033              NaN    1                    เสรี  data is not completed
# 40034  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
#
#                          age
# 0      data is not completed
# 1      data is not completed
# 2      data is not completed
# 3      data is not completed
# 4      data is not completed
# ...                      ...
# 40030  data is not completed
# 40031  data is not completed
# 40032  data is not completed
# 40033  data is not completed
# 40034  data is not completed
#
# [40035 rows x 14 columns]

# %% [markdown]
# ###ข้อมูล hospital

# %%
hospital
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %% [markdown]
# ###เลือก Column ที่ต้องการใช้งานต่อ

# %%
alldb2 = alldb[['user','RowKey','date','phone','site','time','urine','ov','PartitionKey']] 
alldb2
# Out:
#                 user                                    RowKey        date  \
# 0               test                                       NaN         NaN
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png         NaN
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  2022-02-23
# ...              ...                                       ...         ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C         NaN
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1         NaN
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9         NaN
# 40033            NaN                            bbuogxulur.png         NaN
# 40034            NaN                            zttpqogiso.png         NaN
#
#                   phone   site      time            urine   ov  \
# 0                   NaN    NaN       NaN              NaN  NaN
# 1            iPhone10,4  05310  10:50:32              NaN  NaN
# 2                   NaN    NaN       NaN              NaN  NaN
# 3            iPhone13,4  05087  09:59:47  ปกติ (เหลืองใส)    0
# 4            iPhone13,4  05087  09:44:06  ปกติ (เหลืองใส)  NaN
# ...                 ...    ...       ...              ...  ...
# 40030        iPhone13,4  01234       NaN              NaN  NaN
# 40031        iPhone10,5  01234       NaN  ปกติ (เหลืองใส)    2
# 40032        iPhone13,4  01234       NaN  ปกติ (เหลืองใส)    1
# 40033  Samsung SM-A115F  01234       NaN              NaN  NaN
# 40034  Samsung SM-A115F  01234       NaN  ปกติ (เหลืองใส)    1
#
#                  PartitionKey
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 40030     เกษศิรินทร์  ไชยลาภ
# 40031  เถลิงเกียรติ เสริฐเลิศ
# 40032                    เสรี
# 40033                    เสรี
# 40034                    เสรี
#
# [40035 rows x 9 columns]

# %% [markdown]
# ###ตรวจสอบค่า Missing ข้อมูล alldb

# %%
alldb2.isnull().any()
# Out:
# user            True
# RowKey          True
# date            True
# phone           True
# site            True
# time            True
# urine           True
# ov              True
# PartitionKey    True
# dtype: bool

# %% [markdown]
# ###ตัดค่า Missing โดยการ dropna()

# %%
alldb3 = alldb2.dropna()
alldb3
# Out:
#          user                                RowKey        date  \
# 185     85879                        shmpdrmtgc.png  2022-03-24
# 186    45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23
# 187    45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23
# 188     27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 190     06223                        kfpwuaqldj.png  2022-03-23
# ...       ...                                   ...         ...
# 40013   ttest                        crqcufokmn.png  2022-02-21
# 40014   ttest                        gzxgflnowr.png  2022-02-21
# 40016     xxx                        jytlopevha.png  2022-02-17
# 40022     yyy                        ivccsksowb.png  2022-02-17
# 40023     zzz                        psudrnccsh.png  2022-02-17
#
#                    phone   site      time            urine ov PartitionKey
# 185         OPPO CPH2293  05194  13:08:39          มีตะกอน  0         0000
# 186           iPhone11,8  04312  09:45:28  ปกติ (เหลืองใส)  0       0-1528
# 187           iPhone11,8  04312  10:06:45  ปกติ (เหลืองใส)  0       0-1544
# 188           iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0         0000
# 190    Xiaomi 21081111RG  13777  16:31:45  ปกติ (เหลืองใส)  0        00000
# ...                  ...    ...       ...              ... ..          ...
# 40013   Samsung SM-G998B   test  14:23:45             ขุ่น  2         x001
# 40014   Samsung SM-G998B   test  14:23:43             ขุ่น  2         x001
# 40016   Samsung SM-N950F    xxx  00:01:06  ปกติ (เหลืองใส)  3          xxx
# 40022   Samsung SM-N950F    yyy  08:41:05   มีเม็ดเลือดแดง  2          yyy
# 40023   Samsung SM-N950F    zzz  08:41:04          มีตะกอน  2          zzz
#
# [38663 rows x 9 columns]

# %%
set(alldb3['date'])
# Out:
# {'2022-02-15',
#  '2022-02-16',
#  '2022-02-17',
#  '2022-02-18',
#  '2022-02-19',
#  '2022-02-20',
#  '2022-02-21',
#  '2022-02-22',
#  '2022-02-23',
#  '2022-02-24',
#  '2022-02-25',
#  '2022-02-26',
#  '2022-02-27',
#  '2022-02-28',
#  '2022-03-01',
#  '2022-03-02',
#  '2022-03-03',
#  '2022-03-04',
#  '2022-03-05',
#  '2022-03-06',
#  '2022-03-07',
#  '2022-03-08',
#  '2022-03-09',
#  '2022-03-10',
#  '2022-03-11',
#  '2022-03-12',
#  '2022-03-13',
#  '2022-03-14',
#  '2022-03-15',
#  '2022-03-16',
#  '2022-03-17',
#  '2022-03-18',
#  '2022-03-19',
#  '2022-03-20',
#  '2022-03-21',
#  '2022-03-22',
#  '2022-03-23',
#  '2022-03-24',
#  '2022-03-25',
#  '2022-03-26',
#  '2022-03-27',
#  '2022-03-28',
#  '2022-03-29',
#  '2022-03-30',
#  '2022-03-31',
#  '2022-04-01',
#  '2022-04-02',
#  '2022-04-03',
#  '2022-04-04',
#  '2022-04-05'}

# %%
set(alldb3['RowKey'])
# Out:
# {'562CA917-A768-4E58-B07D-299BE6774748',
#  '3AB78FD5-6BC4-4C48-85AE-B1E2F00AD107',
#  'D2B0AA39-E647-4DBF-846F-0EC8DBB0D2A8',
#  'E3D8025F-DB4B-414A-9A4A-7F8F05C8CF5D',
#  '3F5A4028-44B9-47E2-978F-123416758937',
#  'ctodztzrpg.png',
#  'jtjtghcjhn.png',
#  'khtfcocrbg.png',
#  'DB0BFBEB-FCA3-4163-A46F-ED0BE2602972',
#  'kekyuitxgm.png',
#  '170FE0D8-B449-4870-B919-27EF0BF11950',
#  'dpxqvjzygi.png',
#  'AF946884-5E27-4B2B-B6A2-4AA7BD8D3DAA',
#  '83F7C51C-AA03-4908-9532-6E068D6A0B1B',
#  'spqxvfzkxl.png',
#  'nudjzivpzl.png',
#  'qfgvxpchur.png',
#  '56078C7E-345F-48D2-B7C4-D2618EBF7296',
#  'gpixizemdc.png',
#  'nwvgwgcojp.png',
#  'yhininyxis.png',
#  'epsfvblyqv.png',
#  '7766BD16-E14A-4430-9478-9DCC38C52449',
#  'nbqqvhlqog.png',
#  'lldxhtsmvx.png',
#  '843762C6-E523-466D-B049-33F84DF15FF4',
#  'E1E9616A-ADD6-4C3C-B8DB-F23DA814DE33',
#  '8739D10F-F10A-467B-888A-07D4EAD6544A',
#  'seybkfvkob.png',
#  'C9443059-3EDD-457F-8CB5-35F4050B6EA0',
#  '4D727F50-E205-4B06-A40D-00F84B0D3B80',
#  'gklnxthgft.png',
#  '8CFB2D4C-4107-4827-BB4F-AB0CED3E0918',
#  '0A7D74C7-352B-4B5F-A86B-54E8214BA6C8',
#  'cmuzmwwguy.png',
#  'uwwytwjffn.png',
#  'EA7C82DE-8111-4788-8835-FAB32FE3EF81',
#  'ufjyqfrfza.png',
#  'xmquzgsgoo.png',
#  '7FC96DB8-C9D8-443D-8278-E4ECD3A26074',
#  'A23F302A-4B21-4CD9-9962-31DEEC07F766',
#  'B7FBB94B-8616-4855-9E5E-FD968DFAD213',
#  '34020511-560F-4144-8533-03B21FE90F28',
#  'baatpziqad.png',
#  '8D3078B1-F749-4D64-8E73-998C6899C427',
#  'qtjuoycebk.png',
#  'D6AD311C-0B1C-4706-AC81-D665F0E6AEC7',
#  'urtyzniwbi.png',
#  '2356B4F2-BDCD-47EF-A9AF-8CBC9C26F823',
#  '75CC7B44-E6EB-42C0-9DD1-DA04822B780C',
#  'F7B5A60A-ADAB-4670-8C5E-CE2AAF5CAA87',
#  'xlvlqazgdl.png',
#  '44DB2C3F-933A-4C50-8A17-ACD0FC38609F',
#  'pyoanrmnyd.png',
#  'ffefqmswge.png',
#  'oqlzbamkyb.png',
#  '3CDA26D3-8B53-4331-9219-478FFB9D321C',
#  'E1F37452-0B55-4DDB-B8F1-CB400C8BE9E5',
#  'savizvawob.png',
#  'CEEF4C1F-0856-4017-A4E0-F4960A130B94',
#  '55E043B4-AFB9-4A7E-88D5-667590D8BE3D',
#  'bjohwttmfy.png',
#  'pttzpkbhet.png',
#  'ldtidsgrkh.png',
#  '41A4F6E2-4E25-4D37-A8FD-B70F4CA5702C',
#  '18EEA562-FD96-4183-B9CF-8E808C9DC640',
#  '103BAEC6-ACAC-45E0-8553-435F287A5D5B',
#  'olxpjtlspt.png',
#  '0714BC7B-9D2A-40D4-98F4-5FA90462CE57',
#  '33DEEAA4-AA30-414E-BB40-E0E7C7D9404B',
#  'ueelixlset.png',
#  '03358985-C616-4578-A259-ED4473CE432C',
#  'C012179D-D8C5-442B-A53F-5AA50F0B207F',
#  '1A2579BA-1E4C-495F-8C4F-80B00C724570',
#  'ycsztengih.png',
#  'C6028C0C-F66A-4DBC-B97C-DE017D2D6E96',
#  'lzcxnpybls.png',
#  '26A03116-523E-43C6-8D51-C1414B163C0D',
#  'xiywdgdffl.png',
#  'xuccfftxvz.png',
#  '55DEC62E-7781-4D22-BFC7-ECAD21B15484',
#  'aeljmaamls.png',
#  '981E91A1-8FF9-4B04-B2AD-5B0F51B7AF08',
#  '87085CCD-1DB4-4256-8958-40C4F697F16C',
#  'D05738CD-06AD-4525-8B0C-9BC03726D5E2',
#  'ccihazfidp.png',
#  '5746255E-7AB5-4E17-8203-A30F4A94D954',
#  'xrsvxfjyiv.png',
#  'vajiomyauc.png',
#  'nocutliufl.png',
#  'yfdrdvdujp.png',
#  '302C338C-759D-4B1F-AEB2-D8A76D2FEDAA',
#  'dlgrumkzmh.png',
#  'A06637A2-A735-49D6-8FE8-A6483C2D71CA',
#  '52DFA918-7BF3-46D1-8880-271C23B97658',
#  'hwkjlpvfem.png',
#  'E16EFE50-5072-4965-A43B-812431ACD09F',
#  '990054B0-F651-4367-9AC4-CCB38636BFC4',
#  'npuxeltkpq.png',
#  'jzuxxrhwpo.png',
#  'C84C4B5D-D8AC-4BEF-B441-8987FE0EA58D',
#  'tapgqlphdb.png',
#  'A790BD2E-ED55-4A15-8921-03FB8F1A26DB',
#  'wenxbzmezc.png',
#  'pkcrixxndd.png',
#  '913F5ABD-6477-4912-96B4-5DDB71153E20',
#  '675EC7E6-9D35-427F-B185-8FC3273B0A0C',
#  'AE0AC11C-523A-4386-9A63-70F5491D8B4B',
#  '08FE9CF7-4FA5-4739-8686-81AB769B62DD',
#  'vowpmqmici.png',
#  'yefmugjgpp.png',
#  'D8167802-180B-43B9-85E6-A3564CC03FEF',
#  'C8490B30-C28F-4BC0-B1B5-F25B576D5512',
#  'titxrvkxas.png',
#  'BD074137-8548-4F20-9B44-9536BF1FF9FF',
#  'pnnwcvydou.png',
#  'AE89DBA3-0603-464A-9CCD-CC64C826A110',
#  'ttqyaentci.png',
#  'ojnwgcqtde.png',
#  '8800392C-0F41-4719-8C33-5EC38B2D5F35',
#  'awrlsrbryw.png',
#  '286CF003-EFE3-4BDC-93F4-31D916227135',
#  'kkazqarmkv.png',
#  'rjdjrvgtoq.png',
#  '2DAB51C9-62F4-450E-8FA7-52A9EEDA9DF9',
#  'yzygirpbao.png',
#  'gjtbxncdmz.png',
#  'EC2CFFAD-E805-4D36-BE49-2BFB618B7665',
#  'pcmmduwyqs.png',
#  'A738BB21-E5B3-48FA-9A41-2E14DCE8C234',
#  'qwikseqnmy.png',
#  'F1DEB6E1-51C3-4B61-9BFD-7EA56D5EC737',
#  'pkumwcxmwp.png',
#  'D65FD3C5-5B90-44C8-8149-B716B9F2C66B',
#  '06BB62C8-DE74-42F4-A595-23819D76D6C7',
#  'DDBF0405-DC74-4E42-BD29-BCC99858D8C8',
#  '0E8763F9-B34F-4417-B538-1A9901712AFF',
#  'lercbcgrex.png',
#  '620D733F-3FB2-4B22-98DB-BB2D99F6CE67',
#  'sqmpylmrir.png',
#  'fegxblixky.png',
#  'D107E788-4E08-4A7F-A10D-782FDA8E0651',
#  'oxfxwqcxpg.png',
#  'yjivtqsgrq.png',
#  '96CB4E15-EE80-4023-83AF-B965C7D35E30',
#  'oxeeevnesw.png',
#  'B0E4B1D3-48E3-4090-ABAF-5E6D8C69DC70',
#  'E23F39D4-918E-4A08-8677-55990C1228F7',
#  'A25DD640-86EF-42E2-9B9D-340A6138A58C',
#  '2B92A585-DF04-4DE7-90AD-F8E395A56424',
#  '2AC9C410-B27B-4A99-8975-CF7A534D5B82',
#  'EF470E06-4BDF-4238-A020-7A0482390F19',
#  '07C87DA1-12EE-4B53-A3F2-08411D886C52',
#  'F3EECA0E-1B1F-45EC-AEA9-98BD7B4595EA',
#  'xsllcbtqzj.png',
#  'CB563189-1B9F-4676-9531-1F377CB21552',
#  '485DF154-12FB-43BB-A401-0CF33CB9EC02',
#  'F5A4E537-5C21-4334-835D-3ED7C324A276',
#  'CC0A9D26-078E-4333-A41E-F298A942383F',
#  'wpqraclvng.png',
#  'krjxnbzbdo.png',
#  '7792522D-F267-4EEB-A042-B282490FBD3A',
#  'bzaazvobzo.png',
#  'bpspqebtfw.png',
#  'D1EC80F9-441A-4363-898C-5859E853BCBE',
#  'yhmrcbqgcg.png',
#  'C59E95E5-8B5F-437D-8409-66D0ECC44674',
#  'wbuhtpwdxg.png',
#  '6960DB5E-872F-4805-B49C-35064113634B',
#  'qkhinoklfy.png',
#  'D218E253-5EF8-492D-83A8-C356AD716A89',
#  '9FBEA469-A0B2-4100-B5E7-A9F0568DC91C',
#  'BCC4685E-754D-423D-8501-048C5DF6916D',
#  'rlqmfmgdwc.png',
#  'twonvskcvm.png',
#  '9920721F-6619-4988-9741-6DCB7D8E977D',
#  'tjhelxtggt.png',
#  'gxikolmarc.png',
#  'kbqibjmiik.png',
#  '87337FF3-0C8D-4DCD-B9CB-CA4B3493FAF8',
#  'fihsfbnnyc.png',
#  'ahjnhbjcnv.png',
#  'gqbswshjyz.png',
#  '9E646E1A-40E7-4E7F-BAE2-1ACBD6A70E4E',
#  'bwwhnlxxdi.png',
#  '4A04907A-DBB4-4068-B5C6-B9533894CE12',
#  'epgtfmuesc.png',
#  'AE06A124-45AD-4A38-B0EB-6609BBA48FFF',
#  'D36D23B9-EF32-43C1-9919-8E47690A8E6B',
#  'EE6F0422-B455-493F-A5E0-0BA9F3C339CE',
#  'C3EBF974-8401-48A5-A049-6424EEB1D809',
#  'qhklqisvks.png',
#  'C07236FE-8448-4C3F-9AD7-B94B99873F42',
#  'rytfvcknny.png',
#  'mzzysadptj.png',
#  '2054BCA0-BB33-4BA7-BCF2-317CBA76E852',
#  'rbgfxyhyng.png',
#  'kqfehulnhh.png',
#  'edmtaycxcz.png',
#  'F6FD014B-8EBD-4485-866B-BAEDC781D0F0',
#  'wzxempomyk.png',
#  '365320EB-B26D-4159-87FE-F3527E466551',
#  'BA78954C-A7E8-4B47-8F36-7082690AEC7B',
#  'ombzaopeuk.png',
#  'verbescyaj.png',
#  '9184E1F3-BE9B-4CC7-9C37-71524FD31AFE',
#  'cnvwsrohhn.png',
#  '1CB02A95-1E28-4D88-8466-3E00CC9EB91D',
#  'zrzyrcxakj.png',
#  'uqxcmfufyv.png',
#  '9625B4B3-215A-45F1-8684-8B529051C0F0',
#  'iuggdnilpv.png',
#  '635D7B06-9AF3-4659-8971-706C50C029E1',
#  'ED9C6BFB-A6D5-4A52-9D13-E026DB6CAEF1',
#  'B0BF2DE5-AA8A-4F1F-A988-DF61DDCACC4E',
#  '4F458EA1-D2EC-4246-A470-07F60FDE6739',
#  'klnrlvrunl.png',
#  'vfvqnspbop.png',
#  '6EE55452-47CA-404F-BB86-0429E06BFE7B',
#  'bntkkzlawk.png',
#  '7D050CE2-DE7F-484A-99A9-C6A4F7E47725',
#  '48B6C8AE-63E0-4E74-B246-0711BB4008F7',
#  '70956AA8-5FFC-4C43-AA80-3504DC52525C',
#  '58C387DE-E33D-4139-A9B0-CE9C0AD30164',
#  'E9D71BED-6372-4BA7-B8EB-E1E1599501F2',
#  'A2148940-F796-4D7A-AA64-5D1E536CD086',
#  'vrxajbibfi.png',
#  'zcopyaiuqc.png',
#  'F08E00BB-FCA1-4B6E-9B80-AEBA38E3F522',
#  'xiqqwubekg.png',
#  'rpbcjhazzv.png',
#  '945B91B4-3726-4576-85D5-D11B22B74E9A',
#  '0E76EB4D-8849-4AAB-BF7C-E9A30357AB9C',
#  '98FA6823-A94D-4F1E-9094-7691679C7614',
#  'mgzuoydwip.png',
#  'B8573E78-F575-40E4-BCA8-BFC85CF7B162',
#  'yqfwnataxb.png',
#  'wwzvrjxjbi.png',
#  'E16DAD1D-B41A-4A16-A82F-7DCABE1C34FA',
#  'C443B0D9-BA31-422F-A191-F3D4D16C34FC',
#  'nznqqouhcs.png',
#  'E14189B1-359F-46A4-A053-734341759C95',
#  'E6E6B8FC-9B59-4CE8-B980-6F86E8BF7A18',
#  'bopdedelnu.png',
#  '9C4BF133-11FA-48D4-AA2E-92871282FCA7',
#  'bduqnzopkp.png',
#  'nzewvnjvoq.png',
#  'E24B84B9-D542-4031-93D9-3D0E65257133',
#  '7D9A6900-88D5-41FA-9C98-6EF9DB396C94',
#  'uxgkbeoxwp.png',
#  'gbhncsfuos.png',
#  '6D04FCC5-4864-4E50-8F1D-95B74BCAD0CD',
#  'pazelzbjeb.png',
#  'ABBA7E2A-87B5-4BB3-94BB-F55D7688A61F',
#  'xgpvsrjmby.png',
#  'hezzndufpg.png',
#  'E01BC959-6433-4701-8E6B-7F90AEF31F65',
#  'sbtzkjynvk.png',
#  'hrqgpvdysv.png',
#  'BE20F2D8-09E8-47FD-BEDB-1533B3961177',
#  'gazrsrisuw.png',
#  'dlahcucqzc.png',
#  '9F0A49F4-928B-43B0-A0CA-2D7165994475',
#  'pqpcuknbax.png',
#  'hmkegutjoj.png',
#  'rytrwjqmrc.png',
#  '4DBA2FD5-5C13-4858-A15F-420B7CBDE130',
#  '26053E7E-F27C-4F4F-A991-8F757E30ECA5',
#  '61582E4E-E191-43E7-A475-CE2766A70FEB',
#  'sumdufpsbb.png',
#  'gqmqgapwdt.png',
#  'budgrvucbr.png',
#  'xlycvabwwn.png',
#  'C88E46CE-193E-40DC-95FF-4CFBC48AADEC',
#  'zycishgacn.png',
#  'kuvqjzejgw.png',
#  'hynojkvawj.png',
#  'kyanxenkqd.png',
#  'xjuefcfvth.png',
#  'B2D3EEA7-7688-4B1D-82D6-ACDE39F3BB5F',
#  '1746F30C-F49A-4671-9BA8-897CAC880D3E',
#  'paovntrsyx.png',
#  '8C32AF3E-1C95-47A2-8552-BC660582909B',
#  'ekxopezqvk.png',
#  'D2BDD248-2EEF-476C-B1A8-F01DEC6A318D',
#  'kinfvzkdpx.png',
#  'E559CA74-E05D-4CEF-93C8-A22B009E4DF8',
#  '1E3F391F-DE40-433C-8546-5DFB82E7494C',
#  '9A4E9262-9048-42D3-9C92-0EBE26CF347D',
#  'E933FC36-956A-460C-B921-24D9822CEE67',
#  '8445A4DE-A969-48F1-92C1-51750CE4BAE3',
#  '8C69797B-8B4F-4390-A2F3-6FB40394E1F4',
#  'F497DB0E-EB2C-4D89-BE49-C03EFFEA6AEA',
#  'jplxbxlviw.png',
#  'hqvfehozqs.png',
#  'B18AAB5B-D2E5-4E2A-9DEB-8CBBE193EA8F',
#  '2B7B5BBF-A491-4259-B127-894E3E7D6E83',
#  'ruwbpvhthm.png',
#  'A6341CC2-5528-4D88-B2FA-25703A9ABDEF',
#  'eiogxzqsuj.png',
#  '89491865-1E7F-48AF-82D4-B17C8F33AC58',
#  'jejchrweny.png',
#  'F7863645-B506-4BE0-AE06-98445DD3CD8E',
#  '3DA2DCEB-1B01-492E-9DC7-1585502A773A',
#  'xkthzbdusl.png',
#  'pawdhydami.png',
#  'zhxydbeavn.png',
#  'lbmjghrtek.png',
#  '0ECF9731-5A6B-41AE-9F7F-C957DC2F5AF6',
#  'kbqcuzveim.png',
#  'F42A7C31-718C-4378-A656-8F2583C3DD30',
#  'eeqssrrnhk.png',
#  'zouhnhmzbu.png',
#  'AD369D93-F02F-43C3-92B3-295E9A18E0C7',
#  '5EFC2ABF-2678-4207-984F-A38F28F17291',
#  'kldzhcispy.png',
#  '0C99CC01-60A8-4F84-8D60-203F4ADE8E5B',
#  '97F01805-4C0F-4478-9D0F-FF6A5A0B45B5',
#  'ovftgmakah.png',
#  'B851493D-474A-4FCC-BCC3-7E5783121544',
#  'twvseenmrr.png',
#  'fuxpfvwjvj.png',
#  '6F8FC47D-2CCC-4BF2-839E-52D0B6C2A076',
#  'AA82B3B5-46EC-4842-86E5-207AD82478EE',
#  'qvzwjvijii.png',
#  'rilmgskspp.png',
#  '31183DA7-7E09-4528-9DEE-F55193C214C9',
#  'F7BD74A0-616F-4332-BA0D-669191412165',
#  'erfdbhgczp.png',
#  '9099260D-6B74-4138-AC7A-53835DFA2428',
#  '48780AF2-3173-44A4-A001-AB0568B8FA15',
#  '70B08A77-6621-4540-81D8-B96B75A7D2AD',
#  'eguqpzvepr.png',
#  '93095E91-6AF4-42F2-9C8B-7BA44ECF78CD',
#  'zsfrvdqree.png',
#  '0225DBC1-D862-4635-BC3E-EF5C777C7ECF',
#  '39DD0A7A-3054-405A-9CF8-041C9D07916D',
#  'ovoluggtbj.png',
#  '9B36931C-9A1A-4F40-A976-CEDA24005492',
#  'fhgqsnyaaq.png',
#  '0FC1F91C-881D-495E-9C92-AE6A4167E7BB',
#  '9ABBDAE0-E805-428B-984F-92B383B98DA7',
#  'tidwkakhzu.png',
#  'qnunabsalk.png',
#  'ahbaivsrhq.png',
#  '32E7BF03-FC0D-42F1-8547-420F615477B7',
#  '6DB316C3-FA60-406D-93F9-A9EEC9750CFB',
#  'gtdwtjyjsr.png',
#  'kfwumvfkyt.png',
#  'tkdszdbqwz.png',
#  'tozexalxgx.png',
#  '56043506-7A60-45F1-83A5-325236C0FD9D',
#  '57A941E2-1C5B-4A6C-87B3-F51FF7246B80',
#  'boiomggsiy.png',
#  '26E65E68-4C66-4AE8-B1CC-550D0A6E7F11',
#  '1387A6B3-C957-4D9B-8195-1492DEB9832B',
#  'amgfbxpkgo.png',
#  'qkiokobkwc.png',
#  'lccjehjxil.png',
#  'FD76FD6F-2F2D-466A-9278-714A9C073212',
#  'cuzeonmwnq.png',
#  'edkgpqlffj.png',
#  'E22F40B5-C1B7-4560-807D-C0AE844AE965',
#  'E404E913-BBF6-4EE3-A4C8-335133936186',
#  '8E6DE2DB-89F2-4BF3-A6B3-439F55CC7993',
#  'lojjkuntoe.png',
#  'D47617E8-C20A-408E-9E57-8E6669AA6C96',
#  'oxqhlepbeh.png',
#  '6F7A6CBC-9CB3-4B1E-86E7-940C7EF967B9',
#  'cbtrdxjuam.png',
#  '4DC37365-0208-4540-B29B-FC0EF4D9D9B5',
#  '4E20E9E8-65EC-4F86-9272-573E080E8F91',
#  'tehmuuqkuy.png',
#  'clhikthpyl.png',
#  'D16A0FB1-F317-4981-8605-C43847E80A4A',
#  'rzhibfwkxq.png',
#  '71B7AFFF-486D-4393-91C2-D83ABA809604',
#  '63796E08-8380-4215-8F48-2FE08BB63B79',
#  'ECA02F41-3A42-430A-820B-B3D6DC7E72DE',
#  'dkhbnqntfx.png',
#  'zfhmmpvqit.png',
#  'ubhbkiwjrl.png',
#  'kcjkvbslvh.png',
#  '8676B894-4453-4591-86A5-36FB1D608F81',
#  'rgmkknbpvg.png',
#  'tikiurtinh.png',
#  '026FD857-F533-4AF4-A269-19E1C81ECA92',
#  'dgryerixvm.png',
#  'qpxmtgaafc.png',
#  'D680C4ED-0F51-46B4-B1D9-081F45607AC7',
#  '939318EF-A972-4DD4-AAE5-0CFE8E57D864',
#  'tjogafueyl.png',
#  'CE7B93EF-129B-4DEE-A8E4-D460FC19A7BB',
#  '1A9179C8-44BE-430A-AA95-C9F55889B19E',
#  'DF0A99F1-9919-42AC-8FE1-D1FB52E04783',
#  'EA0398D1-0E37-4FAA-9057-D02D63D31742',
#  'A9C55229-6838-43B1-8705-9E14613C2498',
#  '0C506FA8-C53D-4017-96A3-304979EA2CFB',
#  'nwmfyzvjcs.png',
#  'xrzufhyzos.png',
#  'lovunvglbs.png',
#  'mwvthrgtwp.png',
#  'oowcrmgbtu.png',
#  '2D0A7E26-FBDA-4D14-A14F-D3BC0CDA63A2',
#  'zwekdvqbto.png',
#  '008810C2-EDFD-4B06-AEF4-4B1ED56B3008',
#  'A4264D88-F9A3-4FEF-98D8-63E43B2AA493',
#  '78C63300-5ADB-4817-BD6D-85E79608E2A0',
#  'xvhuehixbt.png',
#  '562695D1-1CC8-4E24-9CFF-AF01EBF0FF65',
#  'B2B5855A-AEA7-43E3-B65D-83E25E75D2E9',
#  '29431F53-58A3-4C6E-A234-F0A85786BAE2',
#  '6DDF8817-4161-459C-B903-C45B893B860B',
#  'B47331F6-62AA-4589-8A93-A532E9A9DA12',
#  'CF6B5472-1097-49D4-8B4F-E086D4D77791',
#  'azvguvdixb.png',
#  'asqiwcbtop.png',
#  'vsekolscva.png',
#  'A7B573D5-A980-4026-9837-7F732C2BDC26',
#  'kikyxwjgzy.png',
#  '3F48006B-1770-40A6-BAFF-ABB7D337F646',
#  'edotxacpnl.png',
#  '3B968244-B0DC-4112-993F-4A4EEAB4F042',
#  'iislceupnk.png',
#  'iuukitfrym.png',
#  'pplqiupvbw.png',
#  'C398CCE1-C27E-40E7-A23B-3D37865CA093',
#  'tiopevgkif.png',
#  'lstwonpjnw.png',
#  'eilwgnfknz.png',
#  'yuilnovosi.png',
#  'xpdjitbyil.png',
#  'shfwjhtoeu.png',
#  '0406AD1C-F8E4-4749-BA5C-5B1A07D27449',
#  'jdsbjlzpnl.png',
#  '3CF16605-9F9E-4232-9E1E-8EBCAD2D5C85',
#  '727D9FC0-A860-4BB1-BE41-4F75425D2A9A',
#  'qkqayuokyi.png',
#  'lhdiseyxek.png',
#  'jxswxsppde.png',
#  'bjlcysbqsc.png',
#  'ihivquhjng.png',
#  'nvzmwtdrev.png',
#  'B7059DCF-A320-41E7-939A-71B9D09664BC',
#  'seejnfuyox.png',
#  'ECB0FD4C-0BBA-43FB-AA6C-B530ED57D2E2',
#  '32788B97-429D-46BB-8274-67E11E717E28',
#  'ynnktcmjfb.png',
#  'nmcoelgsnk.png',
#  '24279051-C3F4-4DD4-8A7D-453713CA8326',
#  'rgpuxgddib.png',
#  '36CF9B10-414E-4F1B-AC2B-0303E78CE70F',
#  'eqtfbquvpd.png',
#  'yzektkdase.png',
#  '58E4767E-15D7-42B4-8661-6422BBE5B881',
#  '55F85DF2-DC6D-408F-82B0-BCCD83C0881E',
#  'CA2A5C6D-9278-4F26-B17B-650E6E5D52A1',
#  '6B356446-D16E-4464-A2DC-F54717243C1D',
#  'D54A76AF-31EA-4914-AFBB-35FC9A979B99',
#  'D3CA5392-E5B2-44F9-9D0D-9354657134FB',
#  'B55730FF-4045-49F3-8F89-8D338EC89AF8',
#  'pqcdyrziyq.png',
#  'C847A142-7AB8-49AA-98C0-E91012DEB715',
#  'hnokylgust.png',
#  'D8CFC17C-B595-4059-AB2F-AF39380F859A',
#  '330C84A0-3311-46D2-B291-6EC4E991930E',
#  '8196FB01-E1D4-48FF-9FD7-49A645B394BA',
#  'tzwdicebeb.png',
#  'B1EA62E8-3400-4DDB-929D-6DE7CD3849FF',
#  'qdjiynqbwj.png',
#  '0E418480-0F61-4296-9BFF-56E042D6437D',
#  'jvxpzshvif.png',
#  '415395F7-8E46-4AB0-9118-2C859F0361A2',
#  'pzwylpnwdz.png',
#  'nwmpbjtowq.png',
#  '7AE547F7-1C16-44A6-978A-9025EDA56EEF',
#  'AE7E89E1-1E0E-45B9-83A1-F40CDD22181B',
#  'uvccbgkmag.png',
#  'uyrgkvzegs.png',
#  'fiixxuyrfh.png',
#  'liwhiafwsr.png',
#  '52E523F2-BAC0-4764-8B16-4F39A37C674A',
#  'kgwxbbmqwz.png',
#  'E6D0BB44-0036-4856-8C80-296B5250EB66',
#  'arqrpjcbdc.png',
#  'whisttmtsg.png',
#  '4926D3CD-6E99-4B26-93FD-CDA0AFE2F183',
#  '2ECE0B87-3D81-4FDE-A9FD-CE693D0EC374',
#  'glseppqflc.png',
#  'B807A61A-02D6-4856-833D-4656149003EE',
#  'D1C47CDA-113A-4EA4-A1CB-C09A0F799D94',
#  '64744F0E-5087-4B48-AC04-DBC6C865E8BC',
#  '2287920F-E8DF-4D8E-9B29-F85520DDC9E4',
#  'umvgtaxdaj.png',
#  '59D0B6C1-8E4A-4259-80B5-7283BA22EB8E',
#  'pfltehjhos.png',
#  'BB56D694-986C-4253-8AEB-C728AEE19DD9',
#  'BAF1E812-10B5-4B48-8ECC-DC27C5D5C5EB',
#  '35C399A8-4B4F-40EE-BB29-5CA6964B722D',
#  'lcoxviooen.png',
#  '688A81BA-89BB-4E78-8B64-184346E4E39E',
#  'A631AB68-1C9B-4EFF-B318-91143D461E75',
#  '69C1ABBA-05BB-4841-864C-EC476F636781',
#  'ufupjqsccf.png',
#  'mrdbienaac.png',
#  'kwdgrdwqme.png',
#  'DB82649B-6933-49EF-A7A3-CC745A7D93A3',
#  'AE117B19-5940-4949-BE57-FE95E6014CF5',
#  'tlpdmewdpb.png',
#  'rzdacqrdzl.png',
#  'D7595690-A06F-4C59-BBF7-210B3B5FBA20',
#  '6C8B8789-4956-41AD-A9D2-38193667CB06',
#  'ykobxpjmlb.png',
#  '96666A23-EF1B-4D49-969C-7551336425CA',
#  '69740260-359B-4114-9B62-3DF216A31E0F',
#  'F8F3E45E-BF7E-456F-8FDE-990F61DB641B',
#  'wtlojunxja.png',
#  'toesazhluj.png',
#  'khdvveqcum.png',
#  'D884D0DB-CD20-4C46-867A-0DCC66199AED',
#  'nwrwzqrfgo.png',
#  'vzccfikxll.png',
#  'imdjloqqve.png',
#  '7FE1A803-8140-48C1-A96C-51C27C0A5207',
#  'rsivsxtoqf.png',
#  'guypnzvaqy.png',
#  'aznuejtzyg.png',
#  'gapuiuktch.png',
#  'DEAE3870-86D5-4223-AAE1-0A13F97AF00E',
#  '8B454F07-475D-44DD-8B1C-3733A1766FEE',
#  '3C000FE8-C037-4188-B431-4280B7B38063',
#  'DF7FA917-D712-4F70-9929-DC3BDBDA006E',
#  'DDB088C4-8A4A-4BC8-9BF5-4A455D529E9D',
#  'ujikswrczs.png',
#  '7806F8C3-2229-4E74-9A14-3D992379525B',
#  '27F544BC-F471-4680-881A-F088B6C17BDB',
#  'nlpodenqnw.png',
#  'E2E4D135-78AF-436C-B425-892596AA4563',
#  '5031BD0C-3074-4326-94DD-5FCAA72C29A0',
#  'DE21136C-42A2-44FE-80AC-E03BE60E1804',
#  'FA55A46B-09CF-44D4-80CB-8DEDCB4C47EB',
#  'vitymigrik.png',
#  '3F007E8B-ABC1-4852-876F-9A2C7C391480',
#  '88059236-17B6-4E86-BE4C-F9C12715FE5B',
#  'tmokenriub.png',
#  '4ABF1421-4C48-4EAC-BDC1-15DE5C3EB747',
#  'ipbfzvoezh.png',
#  'rgwmgxkcnx.png',
#  'motfcxiobt.png',
#  'yvesvrxsqh.png',
#  '41D99150-E888-4181-BECE-02A140D2A8C9',
#  'psycqefrxe.png',
#  'F829B082-B328-4025-A1A2-A43050FFC838',
#  'gisdzrrszc.png',
#  'vwrtxhmiou.png',
#  '0A2A9F76-7383-45CF-AE61-D0DCB37BCB44',
#  'hkxzuquoox.png',
#  'tftjvsdnxa.png',
#  'D456D329-9D32-4205-8D80-1E204D0B645B',
#  '13ED3CE3-C921-4578-B92B-2086EC477CDC',
#  'FBA3D6BC-E2A1-4DAD-822E-E63A5F3D1175',
#  '9B3D7D57-CA2F-4A65-8719-D74382A3AB6D',
#  'ewzypqjmzr.png',
#  'ihdwuolrqp.png',
#  'xdbreuxcbd.png',
#  '1C8887D7-86CC-4322-93C8-A899DE7780C0',
#  'jnpdxinmyg.png',
#  'brbcyspdzg.png',
#  'zqtrxpzmkv.png',
#  '982A64D1-26D2-4D6E-924A-1448790DC13B',
#  'stuymqklet.png',
#  'dsllavlgfa.png',
#  '9C1B4DEE-32CB-4FB0-BADC-058E0E847265',
#  'lbqlcrqxli.png',
#  'hmlgcmloei.png',
#  'yactphqyiv.png',
#  '2399ED74-0919-4D6E-93D6-979D97D5651E',
#  'yjfsopwafy.png',
#  'ryavdyycxj.png',
#  '8617D7DA-2D00-481B-8A53-FCA6FA1944FD',
#  '7A1EC6FD-8683-4C08-96D2-052265A72CFA',
#  'plqbeipkxr.png',
#  '34656134-FA81-46B0-8EA9-6A1D6FB055D3',
#  'nxnjzpqyip.png',
#  'bbwrcgiezg.png',
#  '0B420629-1E6D-4B21-AF85-4D9EA7449295',
#  '83EC02C2-BB91-4C8B-8174-C4FD7FF2AEE2',
#  '2A0F5C02-5968-42E7-B83E-0244EDF2C8B1',
#  'kngrksmied.png',
#  '70A7703A-1C23-412F-BFDB-D006B381D26A',
#  'D043CF7D-5805-4C59-9AFB-186758234166',
#  '591EA55A-868F-4C35-9395-AF58A02B47C8',
#  '2323B0F3-81E8-4DD1-AEED-B27B34411B73',
#  'hqocrxgcno.png',
#  'ycdlkuizfw.png',
#  'vatnemlglo.png',
#  'C2ADCA03-3819-4A80-8C70-A2FA9CBEEE07',
#  'fjljdtfuhc.png',
#  'ewqoigmpfb.png',
#  '81B04FF9-2545-4660-8362-2B28C3BE4586',
#  'F548E749-43E9-4841-BD38-DA2E51FE4642',
#  'C6BD439A-DB8F-4784-A748-1A62B099C351',
#  'cfwanrcixf.png',
#  'FC1D16FF-F82A-4D52-8C8B-9D8C2F00631E',
#  'qtzwbpzpde.png',
#  'fggiguyrek.png',
#  'vqdnrhimrv.png',
#  'garwlpesjt.png',
#  'olpyseeadc.png',
#  'F4B6A1AE-FFA5-4BC3-A963-8E0C08BE6434',
#  'B3518FC6-4271-4E0D-8DC3-9E38F93886DF',
#  'eaniwvqsxg.png',
#  'E3EA3E83-2B3E-43EF-9894-E65733CE1566',
#  '52B846B7-9B29-48F0-AA2B-9B738B57D9BC',
#  'wixbncjttl.png',
#  '4879B434-385A-44D2-BEDB-4991020DF36C',
#  'fjdacqjqbq.png',
#  'F394D3C1-4732-462A-8918-808256B88498',
#  'lvtfleiecz.png',
#  '27187EC8-BD56-4223-AD03-1D5734E49FC6',
#  'hpgwfmhbdi.png',
#  'ioovpmkxcy.png',
#  'uwxnrlgwvd.png',
#  'jtufdjdgrw.png',
#  '15892836-01EF-4F89-9437-992AD8C66110',
#  '1D88B2F1-129D-47B4-8A13-9C7F97404BAF',
#  'FBA017E9-2642-4108-B273-8FBE4A3F6FC7',
#  'gizavphqiu.png',
#  'FE541D21-2175-4EF6-85B4-E6B2693855AA',
#  'ndpmxnnqor.png',
#  'kbutzofbdj.png',
#  'nvgpqlqhaj.png',
#  'uxfduegphy.png',
#  'F095497E-D3AE-440C-B06F-9CDFADF6CD0A',
#  'tjjmmggtzg.png',
#  'xprhcwitzb.png',
#  '11BCDB18-302E-4936-A212-2E25D6601C4B',
#  'gkpxhbsgpo.png',
#  'qtzchgjwjb.png',
#  'vzxjspdwrc.png',
#  'oalaypyyzp.png',
#  'E2441722-FBF1-4DBA-9D98-89B2F5079047',
#  '7B0FC974-B5EC-409C-89C9-C99C84D22AFB',
#  'iltrbysiyi.png',
#  'arjulvlijc.png',
#  '5679270B-052F-4160-B44C-49EA37578695',
#  'wmiopludth.png',
#  'ecwsprzgyh.png',
#  'fzzcsnvvyx.png',
#  'bxdarunwiq.png',
#  'yugrnalaau.png',
#  'hzpablomjq.png',
#  '24071AF4-F738-41F5-B308-0523634319A4',
#  '3D8ED6BA-E60F-40E2-8F18-1A539F761F1B',
#  'AE97C2CD-42D4-4EE6-B27C-FA75E0ED6D8B',
#  'ABF36705-F745-4AAE-A6D3-E00777E93AEB',
#  'D42F5182-52B6-4FBF-806D-A8121FE47E60',
#  'E793DD57-64DE-458F-8786-E926F1791ADD',
#  '3F9548BB-43DD-4E23-B0F4-5A92D2540ED4',
#  'xtjrenptqy.png',
#  '26062FE1-2651-4553-A984-25C683A99138',
#  'hkvenyqeku.png',
#  'kfblqjyjrx.png',
#  'BBD21083-74F5-42AB-8D5B-F7B04B574000',
#  '1AF5B885-9516-4A69-8A98-364C95B0A7B5',
#  'htidoudpmz.png',
#  'pgqdgqyhrm.png',
#  '5F392698-5939-43A1-9BB8-BF28FD66C701',
#  'ijgcajatom.png',
#  'buaiurlilk.png',
#  'oxmygyjbeu.png',
#  'wusnicbrrn.png',
#  '50D62858-8358-4A65-80E9-4625473D0773',
#  'E648AA50-0EF2-480F-BF74-DD4C26B5D9B9',
#  'B2511624-027C-4AC6-ACC6-EE77DA304AAE',
#  'wlusbmzwem.png',
#  '220C0A05-6895-4CB0-B98E-215DA1403B40',
#  'pxuoloaxrn.png',
#  'nowrffsnxd.png',
#  '6D72803B-461A-4435-9B12-32BAE5753BB1',
#  'stfakivahe.png',
#  'EF42C97C-2E9D-4FCB-8F34-163221D2FCFD',
#  'E5C30FB4-E4A0-4DA6-9912-CE94A4F9204F',
#  'CD475B7B-44C5-4B13-8568-27F83E9A12EA',
#  'B6A6E790-6D73-4680-B3ED-FF964E1D9624',
#  'qoldovspox.png',
#  '6D04C3DD-769A-4B53-8C95-A2DF502B3661',
#  'kxeivcdrzx.png',
#  'peczmyzxea.png',
#  'rirkmkprlz.png',
#  '3557F052-8119-4A6B-8A9E-4D7DC5F6B3E3',
#  'pxlhdgcexm.png',
#  'txdsavvkwu.png',
#  'F333801E-F419-4E9A-B901-F60516626B46',
#  '58129786-B63A-41C6-88A3-9A600AFCAF62',
#  '70D33B34-7FB6-4A78-8944-239193EB6961',
#  '380FD0E0-3455-4A2E-9DF2-510EB6093999',
#  '25EDA557-93B2-47BE-9AB4-BBE38B031866',
#  '666F0A91-7E53-4354-B561-E460BB0E00E0',
#  'xnjdbdauys.png',
#  '4A03E193-C13A-41B2-848C-D9469705C32B',
#  '8D15D8B6-C2B4-4DDE-8064-5713AA6C9DE8',
#  'vtdvrzlrye.png',
#  'mdfhoblutr.png',
#  'DE8A2BB4-8FBD-4F18-A802-58461678A37A',
#  '746B693F-DBA2-4526-8FDA-5F03FD67A083',
#  'C50E0143-163B-4A3E-9A02-648E6BE37F7B',
#  'ripxwpwyri.png',
#  'fmvzwdyqug.png',
#  'lsnyaodpuw.png',
#  'EFE2F46F-1881-4FC9-96F3-CA45EDF5087D',
#  'dwubckejfl.png',
#  'klnptrguiz.png',
#  '58628370-3980-440F-9CE2-9934A074BAA5',
#  'sivtntzpuk.png',
#  'yjlrccslhq.png',
#  '29B14A97-CC92-4518-A075-D1BBB7BA6B43',
#  'D0B09FE0-780D-4A37-B738-882C4E9F451F',
#  '92ED8A76-B622-4938-8439-C115E8A13CC8',
#  'A58001AF-B52F-4858-9EA5-98024B0B4F23',
#  'qzulzegpst.png',
#  'C94889B4-9735-4C6B-A1B8-D4F3C1A39401',
#  '9C843EF4-22B7-4783-BBCF-BD9FBCDBE225',
#  '8156A6CA-368B-4C39-96CF-7241A99E1609',
#  '46BF04CB-5E64-4DCC-BF77-588EA975AF0A',
#  'trsboescvl.png',
#  '74D56C93-0954-4BEB-96BA-7ECFC6ACA443',
#  'mlbodrgtfw.png',
#  '83CCFAA7-5FCD-4EDC-B929-B238F9A8E791',
#  'CD57746C-8438-4D54-908E-CDD29131A528',
#  '74140A5F-9A15-402C-9BE8-86CBE2CCD7ED',
#  'B23F6793-A37F-465E-8A41-39BDFBBC2FC3',
#  '111DB11D-5B5E-4649-82D2-2BBD5731FB3C',
#  '0A586459-FAF2-4136-90F5-FDCD7E11B0CA',
#  'rajzctqope.png',
#  '77DA2921-0DD4-4FA8-A337-6816AF017547',
#  'hfpcchbfmo.png',
#  'snucmmryxo.png',
#  'scehbssaug.png',
#  'dhxzlcexrd.png',
#  '3C132589-8154-4AE2-B6DA-1C6ED767946D',
#  'A723BC39-98D8-4F95-9A35-5D271C891ACB',
#  'BF10D1E1-7DD6-4078-99C6-D3AA0321131E',
#  'birxrxorue.png',
#  'tsauehmszp.png',
#  '6F021638-E4EE-40E1-89D4-3129105789E7',
#  'A7EBE54B-CE25-4CC6-9532-F643660A28E1',
#  'bevcwmwsyo.png',
#  'DA27D639-66D0-470A-A540-F01CD26053F2',
#  '1D70FD44-40FF-48FD-9422-84239D212C0D',
#  '32B6CBBE-E866-4D99-8A24-2D75A7CF2B8E',
#  '6341D9F4-371D-44D1-A1A5-3DA34C8551F5',
#  'srxbvehliz.png',
#  '615189B8-635F-4468-B653-162AEC9DC117',
#  '5107FE01-AD8A-4BC0-BC16-53241CD1FC26',
#  'EDAC3DE4-417A-4303-9EE1-3E728229F8FF',
#  'aqqzphbtbb.png',
#  'ushbuayxev.png',
#  'D9D4F91F-03F1-4E19-9DDA-A49CDF463079',
#  'jafpzfmcpe.png',
#  'xeqfvkjbbj.png',
#  'hrhumflocd.png',
#  'D198154E-A6BA-434C-AFC8-FA625D2FDB61',
#  'vrqbhiwdah.png',
#  'A1153150-B0C1-4F04-BF9C-04B1EC4DD30C',
#  'thnryowikr.png',
#  '172F0E85-1376-4034-A4AB-DD2F986A9F12',
#  'xvktzhpums.png',
#  'vcpnpemydm.png',
#  'qdpaihbbng.png',
#  'C916FDD7-DB73-40F0-B437-D3B19963BA2D',
#  '4A55F3D8-CFB7-44FA-AD58-5CDAB1F2A04E',
#  'xavesqxvsn.png',
#  'ppmvtiztqi.png',
#  '4C4E55B7-568D-4CAE-AA4E-28550B591C2A',
#  'jylvzapuok.png',
#  'AF40D09F-B712-4DF7-8D0E-41C73C966AEA',
#  'tvcgenlmwk.png',
#  'tswykirubt.png',
#  '629F1108-AE6B-4893-9C15-839451C01159',
#  'gywwwxyhai.png',
#  'D97C5C31-0D94-4757-AAED-DE01579DBC06',
#  'otrbqlkgdo.png',
#  'nnqejwqgxh.png',
#  'bhdbhovkxv.png',
#  'ijjywzgfzb.png',
#  'lbkkikgnvn.png',
#  'mavjxxykla.png',
#  '8ABF4E27-21CE-4308-8EDB-A342F91EC2B9',
#  '6FC03C2F-DACD-4960-83B8-DD23EF4D8FF5',
#  'qqoireekjo.png',
#  '3A5BAEA8-989A-48F9-8655-633E0D728392',
#  'qbyjpptudy.png',
#  'hwtqjqbbgj.png',
#  '45E10746-3500-40BC-BB0E-5E07CF706E79',
#  '73352456-6A2D-43F0-B2EB-C4F6799E4737',
#  'oerdlflhww.png',
#  'wanzsjknvt.png',
#  'lbqtvelqvz.png',
#  'qapdismetv.png',
#  'dzqedeoext.png',
#  'mdfsoopjxm.png',
#  'puzfacycgr.png',
#  'emxjtfouht.png',
#  'D15F05C1-CF35-4179-A703-38B005E779D3',
#  '7ACC1633-19D2-4204-83CA-5879B9FEA63B',
#  'ljswpxtczv.png',
#  '8E0E4CE6-138D-475E-87A1-36ABC81A157B',
#  'xthsyozynz.png',
#  'gikvvyqlft.png',
#  '047E59A1-32B5-4FDE-B344-40E1233C0325',
#  '7B643234-DD8A-4FBA-8F09-A94D9A8468FD',
#  'fekmyifrmd.png',
#  'C56549D8-3C67-41B9-89C8-04D647B375D9',
#  'E66690D2-1A24-44DA-A660-79A0A4DB6AC3',
#  '1B1F9860-3CD4-477B-9938-D22FAA78BD26',
#  'wwvydfcczt.png',
#  'xwfmsnpigw.png',
#  '7E3C0426-A437-4FF3-AE11-40DE74A10119',
#  'wfxscvzami.png',
#  '0C785DC6-E6AD-4258-B32E-FF9CC960472B',
#  'F30BFFEF-A203-42F1-B9D4-B4FFFBBAA75A',
#  '44C4FB4F-6634-4E26-97AA-A8F3ECF623FC',
#  'eylcmngdyk.png',
#  'B663E772-448A-4A5F-BD4F-25598AE0A05D',
#  'tojzrvjuiq.png',
#  'CF7FE633-EAAD-4D8A-A826-38E60B23242C',
#  '74181897-A197-45D7-A248-2AB197CA2A41',
#  'tknipzmadl.png',
#  '33261578-A70E-418F-802D-049E84D1508E',
#  '5BF9A341-C56B-4B76-A7E6-90E86991A98F',
#  'ssemrfxvok.png',
#  'dgppqeefzb.png',
#  'A92F6D12-FE65-4E24-A8F0-A57ACCCD7478',
#  'C6BAA845-B450-4442-BC92-724D11DD2F42',
#  '2CCD2603-D921-4E10-94F0-ABB10DEBDD30',
#  '78E80722-3223-40EA-85A3-705BA7D04BE4',
#  '58481877-F6F4-464F-B57A-B901EFEF3CA6',
#  'B0F4ACA8-EC16-489E-A655-FC94951BFD0E',
#  'C41D7A7C-0852-4001-86A9-7A9B2465DDDE',
#  'jevfajdnpx.png',
#  'fxuijkuimr.png',
#  '59063CC1-0385-4E12-AA50-D2E804475BAB',
#  'hycffjkgxu.png',
#  '96ED8615-D12C-4DF0-AF32-B01D20948304',
#  'aijkdthelr.png',
#  'sbvivfrzke.png',
#  'jmpomdvzmt.png',
#  '1BFC31A5-84BE-452C-A99E-7A205C81B904',
#  'B88C71DF-DCAD-4AD9-AD63-D55EA753843F',
#  '8C66DDB0-98BA-41CC-BC61-12B5D527FBEF',
#  'CF8A02FD-1E79-42EA-BC66-FCE4E138DD4C',
#  'cpldcxgwpd.png',
#  'rhdcygggfh.png',
#  '4DE4EB3E-8A27-4701-BF3D-663F575FADF4',
#  '4EEB8EBA-5B5B-4FB6-B7B0-2F14904DC9F3',
#  'ucixzfsbtf.png',
#  '441CE39A-2417-4150-A644-8726B9DB088B',
#  'D295FB07-21E9-4BAA-AF78-C5801B3E247E',
#  'tslajyjlob.png',
#  '3EC0776D-0047-48E9-8FF0-D06B6CBB6989',
#  'fcptifyfxv.png',
#  'BF532E0D-7A5C-4545-A35D-6F14F1C33D8F',
#  'phllmbmglu.png',
#  'londomiftp.png',
#  '1F17C37C-F742-47CE-B781-C4DEE4C85DD4',
#  'D0A1179D-DE9A-4D71-82D1-D694F400BBEF',
#  '28DC68A8-EFA4-4450-80A4-B140198D1571',
#  'xrleqroeug.png',
#  'klfqekoujy.png',
#  'jannicwojg.png',
#  'yofabkmprl.png',
#  'qlomxlpqob.png',
#  'B7E1DA4C-7611-443D-80D8-4F6D7A94B8E4',
#  'xpdbhqyifm.png',
#  'uyhzatgipm.png',
#  'veahexhgki.png',
#  'CF612E1B-56EB-44A9-9601-FAC98BB78390',
#  'kadavpqjfn.png',
#  '4E5D30D7-D7FE-4EEA-BD5D-B4D983C4481E',
#  'sihgonopxc.png',
#  '0A9A20F4-8CEC-4170-82ED-1C28B826384E',
#  '43B4CF82-BBAC-44B0-BC11-FBDA552AEC25',
#  'repkureztb.png',
#  'C8EF92AD-3EB5-41C6-AA39-7E15369B83AB',
#  '6809DBD7-3594-4617-86F2-D9665B11B01F',
#  'tbwfefrkfh.png',
#  'jxkoxsexxy.png',
#  'eshcvrjqbu.png',
#  '5E075454-EF05-4916-8752-91D81EEB9824',
#  '51F6782C-B8A8-4431-B84B-2AB3DAD7B5FA',
#  'livemdhdwi.png',
#  'wcptnplamc.png',
#  '670CC7DC-5FE3-473F-A718-9A85803AE2CC',
#  'D0EAE986-6A1D-4056-828E-1C947F96646C',
#  'kuyyvdqlsk.png',
#  'atwvzvlgow.png',
#  'gexknpwlyy.png',
#  'qrcrnhsfux.png',
#  'CE7306EE-8116-42F9-B94D-99F747C14758',
#  '1E646C4F-26EF-411B-854C-C71F03EC7CC8',
#  'lzcofbnznv.png',
#  '17DE939D-2570-45C5-843B-7FD8219DA8FA',
#  '32AFABEE-C308-420A-A193-0A245F5232D7',
#  '8B4F1464-5F66-4CB2-A513-B199DC8B1098',
#  'myyxvwlfnh.png',
#  'AF813B9E-FAA1-4027-9B9D-958CB9F98800',
#  '17649589-6A8E-43C3-94C4-6E9F32A13EB0',
#  'ycjfzcpxkb.png',
#  'djxmkfhchu.png',
#  '32BA5359-0FE9-4DAC-B2BF-B23C3C05DA16',
#  'jmscuwppdj.png',
#  'kpnordnlnv.png',
#  'wkamlvazaa.png',
#  'nripqifads.png',
#  'D847714E-2FCB-40BE-AF13-712234E6DF82',
#  '003D1672-6FE9-47E0-864B-A041F387B394',
#  'gflrhvrcsg.png',
#  '9882DCFE-10A2-4066-ACA3-9841FC89A479',
#  '7F261F1F-7B03-4C45-9B52-A166B9A596FF',
#  '71C49F69-2B85-48A4-A27B-901A60521423',
#  'yhiyafqlah.png',
#  '386FFFFF-2330-41E1-84F4-452CBA0FC75E',
#  'svuwottreo.png',
#  'reiyuaqntv.png',
#  '52CF81A8-6882-42A9-BD7F-12260D641257',
#  'ED2DA4F6-6232-4B53-883D-51115D6B8C6B',
#  'jbijkgsoxo.png',
#  'jfbsnhtyzp.png',
#  'xfanfkxxsc.png',
#  'EE0F50F3-0A5D-4E13-8962-B33E86467896',
#  '40024E31-DA05-459A-8EB1-5CC91FF0172A',
#  'vwrfvgmslv.png',
#  '7C41F9E7-287E-452B-82D0-F0BD8BE79908',
#  'A4B51DEA-FE6A-49D1-AB60-001899DDEFBB',
#  'imhmamfvju.png',
#  '99E8C580-5207-4A45-BAAA-98CD398A9324',
#  'EE067D69-1A7D-4C4E-8D56-D9966919D56F',
#  '6A6BB288-7379-4FD4-9942-26E1E316053D',
#  'qhddtsukrs.png',
#  'domdawyqno.png',
#  'yegfpebulm.png',
#  'kzznkqgcbw.png',
#  'B93DC62A-FF76-44EC-A48B-FCC73E7DF849',
#  'EF315536-EB41-4B1E-8112-1091C227F8B7',
#  'gtgemuoayr.png',
#  'ynvsaujset.png',
#  '173BA35D-E007-45AE-B338-24B953A55870',
#  'A31E0E96-AC5A-4E8E-A5D8-C675087E202D',
#  'A442FCFA-D11D-4617-A66A-B833178D09E3',
#  '80EB9E6E-28F7-40BC-A1BB-6E3298550EF7',
#  'ihisnbyxuc.png',
#  '3C645D37-E6B3-4AD0-86BE-60DFCAE74FEA',
#  'mddahneyvf.png',
#  'BD6FBAE5-603C-40EE-B42B-D04C2BAFB138',
#  'xtastthnrk.png',
#  'jbalftiugj.png',
#  'utovkjzlna.png',
#  'dcgvvsvyxy.png',
#  'kbysarwiru.png',
#  'ddetrdtbpk.png',
#  'D060AC8D-5786-48A9-A93E-ECE867FC4227',
#  '074A4966-DE4F-44E5-8218-C86777184A9F',
#  '08FDABC8-D50D-451D-9F0E-FC167E147769',
#  'mimnguqeni.png',
#  'CD6B70C1-5281-4179-9FD8-C4B9F57C269F',
#  '60FC5C50-5F1F-40BF-A154-606ACF83B8C2',
#  '68BCAF56-770F-4A8D-BDB0-8A72D8DC569E',
#  '0DB22015-4A99-44FD-98F8-5D48A4CDF142',
#  '1177351C-3906-43F5-9D80-C116906C19FE',
#  'kwdpxvmhpl.png',
#  '15CE6FA1-F1AD-4B08-B889-574D62D3C637',
#  'aktaouaoiz.png',
#  '9B336A78-214D-42FD-88E3-596077E9B33D',
#  'gwpmjroutj.png',
#  '9B574A31-7C5A-4257-A127-DAD0D3DDF69C',
#  'jjgfemclua.png',
#  'tltrdygbgl.png',
#  '6CE45112-FA05-4A31-806F-5B355111732C',
#  'inbraypjlo.png',
#  '4133CAF3-BD2A-4D60-A865-F586F7C697A0',
#  'adqkuemdwf.png',
#  'vxfwwkxqrp.png',
#  'D46D7570-364A-4DE1-B443-2121ACE12847',
#  'xwppovotob.png',
#  'brvvjrhrcf.png',
#  '41ECDC47-7690-43FB-A854-7D2522EE5BA4',
#  'pcucgycdxg.png',
#  'tmkocedcve.png',
#  'npwaajaaly.png',
#  '0BBF6866-C3CA-47A3-89AC-059B3FA4055E',
#  '9063E045-4556-4D62-B898-69E47C2B0047',
#  'hbhtebgdmj.png',
#  'tttdvrmjmh.png',
#  'fowvwkaequ.png',
#  '74FA2FDA-2861-4D0C-B165-FC902F00C314',
#  'asuazqhpyk.png',
#  '78553BAA-E64A-4D9C-9027-C1197F4BCBB7',
#  'ruroofecsb.png',
#  'owpwozvjzh.png',
#  ...}

# %%
# convert integer to char
print('65 to char =', chr(65))
print('70 to char =', chr(70))
print('97 to char =', chr(97))
print('196 to char =', chr(196))
print('473 to char =', chr(473))

# convert char to integer
site = 'marcuscode.com'

for s in site:
    print(s, ' = ', ord(s))
# Out:
# 65 to char = A
# 70 to char = F
# 97 to char = a
# 196 to char = Ä
# 473 to char = Ǚ
# m  =  109
# a  =  97
# r  =  114
# c  =  99
# u  =  117
# s  =  115
# c  =  99
# o  =  111
# d  =  100
# e  =  101
# .  =  46
# c  =  99
# o  =  111
# m  =  109
